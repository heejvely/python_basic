# %% [markdown]
# ## 8.1 코드에서 정리

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

def getNgrams(content, n):
    content = content.split(' ')
    output = []
    for i in range(len(content) -  n + 1):
        output.append(content[i:i+n])
    return output

html = urlopen('https://en.wikipedia.org/wiki/Python_(programming_language)')
bs = BeautifulSoup(html, 'html.parser')
content = bs.find('div', {'id':'mw-content-text'}).get_text()
ngrams = getNgrams(content, 2)
print(ngrams)
print('2-grams count is: ' + str(len(ngrams)))
# Out:
# [['General-purpose', 'programming'], ['programming', 'language\n\n\n.mw-parser-output'], ['language\n\n\n.mw-parser-output', '.infobox-subbox{padding:0;border:none;margin:-3px;width:auto;min-width:100%;font-size:100%;clear:none;float:none;background-color:transparent}.mw-parser-output'], ['.infobox-subbox{padding:0;border:none;margin:-3px;width:auto;min-width:100%;font-size:100%;clear:none;float:none;background-color:transparent}.mw-parser-output', '.infobox-3cols-child{margin:auto}.mw-parser-output'], ['.infobox-3cols-child{margin:auto}.mw-parser-output', '.infobox'], ['.infobox', '.navbar{font-size:100%}body.skin-minerva'], ['.navbar{font-size:100%}body.skin-minerva', '.mw-parser-output'], ['.mw-parser-output', '.infobox-header,body.skin-minerva'], ['.infobox-header,body.skin-minerva', '.mw-parser-output'], ['.mw-parser-output', '.infobox-subheader,body.skin-minerva'], ['.infobox-subheader,body.skin-minerva', '.mw-parser-output'], ['.mw-parser-output', '.infobox-above,body.skin-minerva'], ['.infobox-above,body.skin-minerva', '.mw-parser-output'], ['.mw-parser-output', '.infobox-title,body.skin-minerva'], ['.infobox-title,body.skin-minerva', '.mw-parser-output'], ['.mw-parser-output', '.infobox-image,body.skin-minerva'], ['.infobox-image,body.skin-minerva', '.mw-parser-output'], ['.mw-parser-output', '.infobox-full-data,body.skin-minerva'], ['.infobox-full-data,body.skin-minerva', '.mw-parser-output'], ['.mw-parser-output', '.infobox-below{text-align:center}PythonParadigmMulti-paradigm:'], ['.infobox-below{text-align:center}PythonParadigmMulti-paradigm:', 'object-oriented,[1]'], ['object-oriented,[1]', 'procedural'], ['procedural', '(imperative),'], ['(imperative),', 'functional,'], ['functional,', 'structured,'], ['structured,', 'reflectiveDesigned\xa0byGuido'], ['reflectiveDesigned\xa0byGuido', 'van'], ['van', 'RossumDeveloperPython'], ['RossumDeveloperPython', 'Software'], ['Software', 'FoundationFirst\xa0appeared20\xa0February'], ['FoundationFirst\xa0appeared20\xa0February', '1991;'], ['1991;', '31'], ['31', 'years'], ['years', 'ago\xa0(1991-02-20)[2]Stable'], ['ago\xa0(1991-02-20)[2]Stable', 'release3.10.3[3]\xa0\n'], ['release3.10.3[3]\xa0\n', ''], ['', ''], ['', '/'], ['/', '16'], ['16', 'March'], ['March', '2022;'], ['2022;', '1'], ['1', 'day'], ['day', 'ago\xa0(16'], ['ago\xa0(16', 'March'], ['March', '2022)Preview'], ['2022)Preview', 'release3.11.0a6[4]\xa0\n'], ['release3.11.0a6[4]\xa0\n', ''], ['', ''], ['', '/'], ['/', '7'], ['7', 'March'], ['March', '2022;'], ['2022;', '10'], ['10', 'days'], ['days', 'ago\xa0(7'], ['ago\xa0(7', 'March'], ['March', '2022)\nTyping'], ['2022)\nTyping', 'disciplineDuck,'], ['disciplineDuck,', 'dynamic,'], ['dynamic,', 'strong'], ['strong', 'typing;[5]'], ['typing;[5]', 'gradual'], ['gradual', '(since'], ['(since', '3.5,'], ['3.5,', 'but'], ['but', 'ignored'], ['ignored', 'in'], ['in', 'CPython)[6]OSWindows,'], ['CPython)[6]OSWindows,', 'Linux/UNIX,'], ['Linux/UNIX,', 'macOS'], ['macOS', 'and'], ['and', 'more[7]LicensePython'], ['more[7]LicensePython', 'Software'], ['Software', 'Foundation'], ['Foundation', 'LicenseFilename'], ['LicenseFilename', 'extensions.py,'], ['extensions.py,', '.pyi,'], ['.pyi,', '.pyc,'], ['.pyc,', '.pyd,'], ['.pyd,', '.pyo'], ['.pyo', '(prior'], ['(prior', 'to'], ['to', '3.5),[8]'], ['3.5),[8]', '.pyw,'], ['.pyw,', '.pyz'], ['.pyz', '(since'], ['(since', '3.5)[9]Websitewww.python.orgMajor'], ['3.5)[9]Websitewww.python.orgMajor', 'implementationsCPython,'], ['implementationsCPython,', 'PyPy,'], ['PyPy,', 'Stackless'], ['Stackless', 'Python,'], ['Python,', 'MicroPython,'], ['MicroPython,', 'CircuitPython,'], ['CircuitPython,', 'IronPython,'], ['IronPython,', 'JythonDialectsCython,'], ['JythonDialectsCython,', 'RPython,'], ['RPython,', 'Starlark[10]Influenced'], ['Starlark[10]Influenced', 'byABC,[11]'], ['byABC,[11]', 'Ada,[12]'], ['Ada,[12]', 'ALGOL'], ['ALGOL', '68,[13]'], ['68,[13]', 'APL,[14]'], ['APL,[14]', 'C,[15]'], ['C,[15]', 'C++,[16]'], ['C++,[16]', ' ...
# 2-grams count is: 11704

# %%
import re

def getNgrams(content, n):
    content = re.sub('\n|[[\d+\]]', ' ', content)
    content = bytes(content, 'UTF-8')
    content = content.decode('ascii', 'ignore')
    content = content.split(' ')
    content = [word for word in content if word != '']
    output = []
    for i in range(len(content) -  n + 1):
        output.append(content[i:i+n])
    return output

# %%
html = urlopen('https://en.wikipedia.org/wiki/Python_(programming_language)')
bs = BeautifulSoup(html, 'html.parser')
content = bs.find('div', {'id':'mw-content-text'}).get_text()
ngrams = getNgrams(content, 2)
print(ngrams)
print('2-grams count is: ' + str(len(ngrams)))
# Out:
# [['General-purpose', 'programming'], ['programming', 'language'], ['language', '.mw-parser-output'], ['.mw-parser-output', '.infobox-subbox{padding:'], ['.infobox-subbox{padding:', ';border:none;margin:-'], [';border:none;margin:-', 'px;width:auto;min-width:'], ['px;width:auto;min-width:', '%;font-size:'], ['%;font-size:', '%;clear:none;float:none;background-color:transparent}.mw-parser-output'], ['%;clear:none;float:none;background-color:transparent}.mw-parser-output', '.infobox-'], ['.infobox-', 'cols-child{margin:auto}.mw-parser-output'], ['cols-child{margin:auto}.mw-parser-output', '.infobox'], ['.infobox', '.navbar{font-size:'], ['.navbar{font-size:', '%}body.skin-minerva'], ['%}body.skin-minerva', '.mw-parser-output'], ['.mw-parser-output', '.infobox-header,body.skin-minerva'], ['.infobox-header,body.skin-minerva', '.mw-parser-output'], ['.mw-parser-output', '.infobox-subheader,body.skin-minerva'], ['.infobox-subheader,body.skin-minerva', '.mw-parser-output'], ['.mw-parser-output', '.infobox-above,body.skin-minerva'], ['.infobox-above,body.skin-minerva', '.mw-parser-output'], ['.mw-parser-output', '.infobox-title,body.skin-minerva'], ['.infobox-title,body.skin-minerva', '.mw-parser-output'], ['.mw-parser-output', '.infobox-image,body.skin-minerva'], ['.infobox-image,body.skin-minerva', '.mw-parser-output'], ['.mw-parser-output', '.infobox-full-data,body.skin-minerva'], ['.infobox-full-data,body.skin-minerva', '.mw-parser-output'], ['.mw-parser-output', '.infobox-below{text-align:center}PythonParadigmMulti-paradigm:'], ['.infobox-below{text-align:center}PythonParadigmMulti-paradigm:', 'object-oriented,'], ['object-oriented,', 'procedural'], ['procedural', '(imperative),'], ['(imperative),', 'functional,'], ['functional,', 'structured,'], ['structured,', 'reflectiveDesignedbyGuido'], ['reflectiveDesignedbyGuido', 'van'], ['van', 'RossumDeveloperPython'], ['RossumDeveloperPython', 'Software'], ['Software', 'FoundationFirstappeared'], ['FoundationFirstappeared', 'February'], ['February', ';'], [';', 'years'], ['years', 'ago('], ['ago(', '-'], ['-', '-'], ['-', ')'], [')', 'Stable'], ['Stable', 'release'], ['release', '.'], ['.', '.'], ['.', '/'], ['/', 'March'], ['March', ';'], [';', 'day'], ['day', 'ago('], ['ago(', 'March'], ['March', ')Preview'], [')Preview', 'release'], ['release', '.'], ['.', '.'], ['.', 'a'], ['a', '/'], ['/', 'March'], ['March', ';'], [';', 'days'], ['days', 'ago('], ['ago(', 'March'], ['March', ')'], [')', 'Typing'], ['Typing', 'disciplineDuck,'], ['disciplineDuck,', 'dynamic,'], ['dynamic,', 'strong'], ['strong', 'typing;'], ['typing;', 'gradual'], ['gradual', '(since'], ['(since', '.'], ['.', ','], [',', 'but'], ['but', 'ignored'], ['ignored', 'in'], ['in', 'CPython)'], ['CPython)', 'OSWindows,'], ['OSWindows,', 'Linux/UNIX,'], ['Linux/UNIX,', 'macOS'], ['macOS', 'and'], ['and', 'more'], ['more', 'LicensePython'], ['LicensePython', 'Software'], ['Software', 'Foundation'], ['Foundation', 'LicenseFilename'], ['LicenseFilename', 'extensions.py,'], ['extensions.py,', '.pyi,'], ['.pyi,', '.pyc,'], ['.pyc,', '.pyd,'], ['.pyd,', '.pyo'], ['.pyo', '(prior'], ['(prior', 'to'], ['to', '.'], ['.', '),'], ['),', '.pyw,'], ['.pyw,', '.pyz'], ['.pyz', '(since'], ['(since', '.'], ['.', ')'], [')', 'Websitewww.python.orgMajor'], ['Websitewww.python.orgMajor', 'implementationsCPython,'], ['implementationsCPython,', 'PyPy,'], ['PyPy,', 'Stackless'], ['Stackless', 'Python,'], ['Python,', 'MicroPython,'], ['MicroPython,', 'CircuitPython,'], ['CircuitPython,', 'IronPython,'], ['IronPython,', 'JythonDialectsCython,'], ['JythonDialectsCython,', 'RPython,'], ['RPython,', 'Starlark'], ['Starlark', 'Influenced'], ['Influenced', 'byABC,'], ['byABC,', 'Ada,'], ['Ada,', 'ALGOL'], ['ALGOL', ','], [',', 'APL,'], ['APL,', 'C,'], ['C,', 'C'], ['C', ','], [',', 'CLU,'], ['CLU,', 'Dylan,'], ['Dylan,', 'Haskell,'], ['Haskell,', 'Icon,'], ['Icon,', 'Lisp,'], ['Lisp,', 'Modula-'], ['Modula-', ','], [',', 'Perl,'], ['Perl,', 'Standard'] ...
# 2-grams count is: 12709
# <ipython-input-3-ff87007080b1>:4: FutureWarning: Possible nested set at position 3
#   content = re.sub('\n|[[\d+\]]', ' ', content)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import string

def cleanSentence(sentence):
    sentence = sentence.split(' ')
    sentence = [word.strip(string.punctuation+string.whitespace) for word in sentence]
    sentence = [word for word in sentence if len(word) > 1 or (word.lower() == 'a' or word.lower() == "i")]
    return sentence

def cleanInput(content):
    content = content.upper()
    content = re.sub('\n|[[\d+\]]',' ', content)
    content = bytes(content, 'UTF-8')
    content = content.decode('ascii', 'ignore')
    sentences = content.split('. ')
    return [cleanSentence(sentence) for sentence in sentences]

def getNgramsFromSentence(content, n):
    output = []
    for i in range(len(content) - n + 1):
        output.append(content[i:i+n])
    return output

def getNgrams(content, n):
    content = cleanInput(content)
    ngrams = []
    for sentence in content:
        ngrams.extend(getNgramsFromSentence(sentence, n))
    return ngrams

# %%
import string

print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
html = urlopen('https://en.wikipedia.org/wiki/Python_(programming_language)')
bs = BeautifulSoup(html, 'html.parser')
content = bs.find('div', {'id':'mw-content-text'}).get_text()
ngrams = getNgrams(content, 2)
print(ngrams)
print('2-grams count is: ' + str(len(ngrams)))
# Out:
# [['GENERAL-PURPOSE', 'PROGRAMMING'], ['PROGRAMMING', 'LANGUAGE'], ['LANGUAGE', 'MW-PARSER-OUTPUT'], ['MW-PARSER-OUTPUT', 'INFOBOX-SUBBOX{PADDING'], ['INFOBOX-SUBBOX{PADDING', 'BORDER:NONE;MARGIN'], ['BORDER:NONE;MARGIN', 'PX;WIDTH:AUTO;MIN-WIDTH'], ['PX;WIDTH:AUTO;MIN-WIDTH', 'FONT-SIZE'], ['FONT-SIZE', 'CLEAR:NONE;FLOAT:NONE;BACKGROUND-COLOR:TRANSPARENT}.MW-PARSER-OUTPUT'], ['CLEAR:NONE;FLOAT:NONE;BACKGROUND-COLOR:TRANSPARENT}.MW-PARSER-OUTPUT', 'INFOBOX'], ['INFOBOX', 'COLS-CHILD{MARGIN:AUTO}.MW-PARSER-OUTPUT'], ['COLS-CHILD{MARGIN:AUTO}.MW-PARSER-OUTPUT', 'INFOBOX'], ['INFOBOX', 'NAVBAR{FONT-SIZE'], ['NAVBAR{FONT-SIZE', 'BODY.SKIN-MINERVA'], ['BODY.SKIN-MINERVA', 'MW-PARSER-OUTPUT'], ['MW-PARSER-OUTPUT', 'INFOBOX-HEADER,BODY.SKIN-MINERVA'], ['INFOBOX-HEADER,BODY.SKIN-MINERVA', 'MW-PARSER-OUTPUT'], ['MW-PARSER-OUTPUT', 'INFOBOX-SUBHEADER,BODY.SKIN-MINERVA'], ['INFOBOX-SUBHEADER,BODY.SKIN-MINERVA', 'MW-PARSER-OUTPUT'], ['MW-PARSER-OUTPUT', 'INFOBOX-ABOVE,BODY.SKIN-MINERVA'], ['INFOBOX-ABOVE,BODY.SKIN-MINERVA', 'MW-PARSER-OUTPUT'], ['MW-PARSER-OUTPUT', 'INFOBOX-TITLE,BODY.SKIN-MINERVA'], ['INFOBOX-TITLE,BODY.SKIN-MINERVA', 'MW-PARSER-OUTPUT'], ['MW-PARSER-OUTPUT', 'INFOBOX-IMAGE,BODY.SKIN-MINERVA'], ['INFOBOX-IMAGE,BODY.SKIN-MINERVA', 'MW-PARSER-OUTPUT'], ['MW-PARSER-OUTPUT', 'INFOBOX-FULL-DATA,BODY.SKIN-MINERVA'], ['INFOBOX-FULL-DATA,BODY.SKIN-MINERVA', 'MW-PARSER-OUTPUT'], ['MW-PARSER-OUTPUT', 'INFOBOX-BELOW{TEXT-ALIGN:CENTER}PYTHONPARADIGMMULTI-PARADIGM'], ['INFOBOX-BELOW{TEXT-ALIGN:CENTER}PYTHONPARADIGMMULTI-PARADIGM', 'OBJECT-ORIENTED'], ['OBJECT-ORIENTED', 'PROCEDURAL'], ['PROCEDURAL', 'IMPERATIVE'], ['IMPERATIVE', 'FUNCTIONAL'], ['FUNCTIONAL', 'STRUCTURED'], ['STRUCTURED', 'REFLECTIVEDESIGNEDBYGUIDO'], ['REFLECTIVEDESIGNEDBYGUIDO', 'VAN'], ['VAN', 'ROSSUMDEVELOPERPYTHON'], ['ROSSUMDEVELOPERPYTHON', 'SOFTWARE'], ['SOFTWARE', 'FOUNDATIONFIRSTAPPEARED'], ['FOUNDATIONFIRSTAPPEARED', 'FEBRUARY'], ['FEBRUARY', 'YEARS'], ['YEARS', 'AGO'], ['AGO', 'STABLE'], ['STABLE', 'RELEASE'], ['MARCH', 'DAY'], ['DAY', 'AGO'], ['AGO', 'MARCH'], ['MARCH', 'PREVIEW'], ['PREVIEW', 'RELEASE'], ['A', 'MARCH'], ['MARCH', 'DAYS'], ['DAYS', 'AGO'], ['AGO', 'MARCH'], ['MARCH', 'TYPING'], ['TYPING', 'DISCIPLINEDUCK'], ['DISCIPLINEDUCK', 'DYNAMIC'], ['DYNAMIC', 'STRONG'], ['STRONG', 'TYPING'], ['TYPING', 'GRADUAL'], ['GRADUAL', 'SINCE'], ['BUT', 'IGNORED'], ['IGNORED', 'IN'], ['IN', 'CPYTHON'], ['CPYTHON', 'OSWINDOWS'], ['OSWINDOWS', 'LINUX/UNIX'], ['LINUX/UNIX', 'MACOS'], ['MACOS', 'AND'], ['AND', 'MORE'], ['MORE', 'LICENSEPYTHON'], ['LICENSEPYTHON', 'SOFTWARE'], ['SOFTWARE', 'FOUNDATION'], ['FOUNDATION', 'LICENSEFILENAME'], ['LICENSEFILENAME', 'EXTENSIONS.PY'], ['EXTENSIONS.PY', 'PYI'], ['PYI', 'PYC'], ['PYC', 'PYD'], ['PYD', 'PYO'], ['PYO', 'PRIOR'], ['PRIOR', 'TO'], ['PYW', 'PYZ'], ['PYZ', 'SINCE'], ['WEBSITEWWW.PYTHON.ORGMAJOR', 'IMPLEMENTATIONSCPYTHON'], ['IMPLEMENTATIONSCPYTHON', 'PYPY'], ['PYPY', 'STACKLESS'], ['STACKLESS', 'PYTHON'], ['PYTHON', 'MICROPYTHON'], ['MICROPYTHON', 'CIRCUITPYTHON'], ['CIRCUITPYTHON', 'IRONPYTHON'], ['IRONPYTHON', 'JYTHONDIALECTSCYTHON'], ['JYTHONDIALECTSCYTHON', 'RPYTHON'], ['RPYTHON', 'STARLARK'], ['STARLARK', 'INFLUENCED'], ['INFLUENCED', 'BYABC'], ['BYABC', 'ADA'], ['ADA', 'ALGOL'], ['ALGOL', 'APL'], ['APL', 'CLU'], ['CLU', 'DYLAN'], ['DYLAN', 'HASKELL'], ['HASKELL', 'ICON'], ['ICON', 'LISP'], ['LISP', 'MODULA'], ['MODULA', 'PERL'], ['PERL', 'STANDARD'], ['STANDARD', 'ML'], ['ML', 'INFLUENCEDAPACHE'], ['INFLUENCEDAPACHE', 'GROOVY'], ['GROOVY', 'BOO'], ['BOO', 'COBRA'], ['COBRA', 'COFFEESCRIPT'], ['COFFEESCRIPT', 'GENIE'], ['GENIE', 'GO'], ['GO', 'JAVASCRIPT'], ['JAVASCRIPT', 'JULIA'], ['JULIA', 'NIM'], ['NIM', 'RING'], ['RING', 'RUBY'], ['RUBY', 'SWIFT'], ['SWIFT', 'PYTHON'], ['PYTHON', 'PROGRAMMING'], ['PROGRAMMING', 'AT'], ['AT', 'WIKIBOOKS'], ['WIKIBOOKS', 'PYTHON'], ['PYTHON', 'IS'], ['IS', 'A'], ['A', 'HIGH-LEVEL'], ['HIGH-LEVEL', 'GENERAL-PURPOSE'], ['GENERAL-PURPOSE', 'PROGRAMMING'], ['PROGRAMMING', 'LANG ...
# 2-grams count is: 9598

# %% [markdown]
# #### 8.1.1 데이터 정규화

# %%
# n그램을 리스트가 아니라 Counter 객체에 추가하도록 코드 수정
from urllib.request import urlopen
from bs4 import BeautifulSoup
from collections import Counter
import re
import string

def cleanSentence(sentence):
    sentence = sentence.split(' ')
    sentence = [word.strip(string.punctuation+string.whitespace) for word in sentence]
    sentence = [word for word in sentence if len(word) > 1 or (word.lower() == 'a' or word.lower() == "i")]
    return sentence

def cleanInput(content):
    content = content.upper()
    content = re.sub('\n|[[\d+\]]',' ', content)
    content = bytes(content, 'UTF-8')
    content = content.decode('ascii', 'ignore')
    sentences = content.split('. ')
    return [cleanSentence(sentence) for sentence in sentences]

def getNgramsFromSentence(content, n):
    output = []
    for i in range(len(content) - n + 1):
        output.append(content[i:i+n])
    return output

def getNgrams(content, n):
    content = cleanInput(content)
    ngrams = Counter()
    ngrams_list = []
    for sentence in content:
        newNgrams = [' '.join(ngram) for ngram in getNgramsFromSentence(sentence, n)]
        ngrams_list.extend(newNgrams)
        ngrams.update(newNgrams)
    return ngrams

# %%
html = urlopen('https://en.wikipedia.org/wiki/Python_(programming_language)')
bs = BeautifulSoup(html, 'html.parser')
content = bs.find('div', {'id':'mw-content-text'}).get_text()
ngrams = getNgrams(content, 2)
print(ngrams)
print('2-grams count is: ' + str(len(ngrams)))
# Out:
# Counter({'FROM THE': 218, 'THE ORIGINAL': 209, 'ORIGINAL ON': 207, 'ARCHIVED FROM': 204, 'ON JUNE': 60, 'SOFTWARE FOUNDATION': 38, 'PYTHON SOFTWARE': 38, 'OF THE': 36, 'OF PYTHON': 33, 'IN PYTHON': 33, 'RETRIEVED MARCH': 30, 'RETRIEVED FEBRUARY': 30, 'IN THE': 25, 'SUCH AS': 22, 'RETRIEVED JANUARY': 22, 'AS A': 21, 'THE PYTHON': 21, 'ON MAY': 21, 'VAN ROSSUM': 20, 'IS A': 19, 'PROGRAMMING LANGUAGE': 18, 'ON OCTOBER': 18, 'RETRIEVED NOVEMBER': 18, 'ON DECEMBER': 17, 'RETRIEVED JUNE': 17, 'ON APRIL': 17, 'RETRIEVED JULY': 16, 'RETRIEVED APRIL': 16, 'TO THE': 15, 'ON MARCH': 15, 'CAN BE': 14, 'BE USED': 14, 'PYTHON ENHANCEMENT': 14, 'RETRIEVED MAY': 14, 'RETRIEVED DECEMBER': 14, 'ON FEBRUARY': 14, 'PYTHON IS': 13, 'TO BE': 13, 'FOR PYTHON': 13, 'ENHANCEMENT PROPOSALS': 13, 'RETRIEVED SEPTEMBER': 13, 'IT IS': 12, 'STANDARD LIBRARY': 12, 'ON AUGUST': 12, 'ROSSUM GUIDO': 12, 'ON JANUARY': 12, 'TO PYTHON': 11, 'OF A': 11, 'STATEMENT WHICH': 11, 'USED TO': 11, 'WITH THE': 10, 'OTHER LANGUAGES': 10, 'RETRIEVED AUGUST': 10, 'ON NOVEMBER': 10, 'ON JULY': 10, 'PROGRAMMING LANGUAGES': 9, 'SYNTAX AND': 9, 'FOR THE': 9, 'THE STANDARD': 9, 'ON THE': 9, 'PYTHON FOR': 9, 'FREE SOFTWARE': 9, 'GUIDO VAN': 8, 'AS THE': 8, 'WITH PYTHON': 8, 'PYTHON AND': 8, 'TO A': 8, 'FOR EXAMPLE': 8, 'THE SAME': 8, 'PART OF': 8, 'PYTHON HAS': 8, 'USE OF': 7, 'AND A': 7, 'A PYTHON': 7, 'WRITTEN IN': 7, 'IN A': 7, 'PYTHON A': 7, 'PX SOLID': 7, 'MACHINE LEARNING': 7, 'RETRIEVED OCTOBER': 7, 'NEW FEATURES': 6, 'OF ITS': 6, 'PYTHON CODE': 6, 'PYTHON USES': 6, 'WITH A': 6, 'DOES NOT': 6, 'USED IN': 6, 'ARE NOT': 6, 'AND THE': 6, 'AND IS': 6, 'SCRIPTING LANGUAGE': 6, 'SCIENTIFIC COMPUTING': 6, 'COMPARISON OF': 6, 'PYTHON TO': 6, 'PEP PYTHON': 6, 'STACKLESS PYTHON': 5, 'THE USE': 5, 'ON PYTHON': 5, 'PYTHON IN': 5, 'IN AND': 5, 'IS NOT': 5, 'AND SEMANTICS': 5, 'REFERENCE IMPLEMENTATION': 5, 'OBJECT-ORIENTED PROGRAMMING': 5, 'MANY OTHER': 5, 'BETTER THAN': 5, 'RATHER THAN': 5, 'LANGUAGES SUCH': 5, 'IS ALSO': 5, 'MONTY PYTHON': 5, 'THE LANGUAGE': 5, "EDIT PYTHON'S": 5, 'BY THE': 5, 'INTEGER DIVISION': 5, 'MAY BE': 5, 'USED AS': 5, 'IS THE': 5, 'CAN CONTAIN': 5, 'CONTAIN MIXED': 5, 'MIXED TYPES': 5, 'PYTHON AS': 5, 'A SCRIPTING': 5, 'ON SEPTEMBER': 5, 'ARCHIVED PDF': 5, 'PDF FROM': 5, 'DESIGN PHILOSOPHY': 4, 'FUNCTIONAL PROGRAMMING': 4, 'AS PYTHON': 4, 'THAT IS': 4, 'DEVELOPMENT ENVIRONMENTS': 4, 'SEE ALSO': 4, 'HISTORY OF': 4, 'IT HAS': 4, 'IS BETTER': 4, 'CONTRAST TO': 4, 'TO DO': 4, 'PYTHON INTERPRETER': 4, 'HAS A': 4, 'USE PYTHON': 4, 'LIKE A': 4, 'ASSIGNMENT STATEMENT': 4, 'IT ALSO': 4, 'STATEMENT USED': 4, 'THE CLASS': 4, 'A VALUE': 4, 'FROM A': 4, 'FROM PYTHON': 4, 'THERE ARE': 4, 'FLOOR DIVISION': 4, 'THE OPERATOR': 4, 'OPERATOR FOR': 4, 'LIBRARIES SUCH': 4, 'JAVA AND': 4, 'WHICH IS': 4, 'NUMBER OF': 4, 'THEY ARE': 4, 'PERL AND': 4, 'USE THE': 4, 'IS FOR': 4, 'USED FOR': 4, 'SEQUENCE OF': 4, 'EXAMPLE THE': 4, 'WEB SERVER': 4, 'A FEW': 4, 'CODE IS': 4, 'LATEST RELEASE': 4, 'RELEASE IN': 4, 'IS USED': 4, 'THE VERSION': 4, 'VERSION NUMBER': 4, 'NUMBER IS': 4, 'IS INCREMENTED': 4, 'ARTIFICIAL INTELLIGENCE': 4, 'DYNAMIC LANGUAGE': 4, 'A,.MW-PARSER-OUTPUT CITATION': 4, 'CITATION CS': 4, 'EM CENTER': 4, 'CENTER PX': 4, 'PX NO-REPEAT}.MW-PARSER-OUTPUT': 4, 'PYTHON FAQ': 4, 'THE HISTORY': 4, 'PYTHON INSIDER': 4, 'PYTHON LANGUAGE': 4, "PYTHON DEVELOPER'S": 4, "DEVELOPER'S GUIDE": 4, 'IN SCIENCE': 4, 'SISTER-BAR{MARGIN-TOP PX}.MW-PARSER-OUTPUT': 4, 'MACOS AND': 3, 'DUE TO': 3, 'WAS RELEASED': 3, 'RELEASED IN': 3, 'LIST COMPREHENSIONS': 3, 'REFERENCE COUNTING': 3, 'PYTHON WAS': 3, 'ONE OF': 3, 'MOST POPULAR': 3, 'PHILOSOPHY AND': 3, 'CONTROL FLOW': 3, 'ARITHMETIC OPERATIONS': 3, 'TO OTHER': 3, 'PYTHON PYTHON': 3, 'PYTHON COMMUNITY': 3, 'MANY OF': 3, 'A LARGE': 3, 'ARE SUPPORTED': 3, 'EDIT PYTHON': 3, 'SUPPORT FOR': 3, 'ITS CORE': 3, 'LARGE STANDARD': 3, 'LIBRARY AND': 3, 'IN CONTRAST': 3, 'AT THE': 3, 'AND PYTHON': 3, 'THIS IS': 3, 'IN ITS': 3, 'IS CALLED': 3, 'EDIT MAIN': 3, 'M ...
# 2-grams count is: 6500
