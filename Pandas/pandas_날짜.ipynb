# %%
import time
print(time.time())
type(time.time())
timestamp = time.time()
s = str(timestamp)
print(s, type(s))
# Out:
# 1640588547.438335
# 1640588547.4385912 <class 'str'>

# %%
from datetime import datetime
s = datetime.now()
print(s, type(s))

s1 = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
print(s1, type(s1))
# Out:
# 2021-12-27 07:03:15.243525 <class 'datetime.datetime'>
# 2021-12-27 07:03:15 <class 'str'>

# %%
from datetime import datetime
s = '2021-12-27 07:03:15'
d = datetime.strptime(s, '%Y-%m-%d %H:%M:%S')
print(d, type(d))
# Out:
# 2021-12-27 07:03:15 <class 'datetime.datetime'>

# %%
s = '2021-12-27 07:03:15'
timestamp = time.mktime(datetime.strptime(s, '%Y-%m-%d %H:%M:%S').timetuple())
print(timestamp, type(timestamp))
# Out:
# 1640588595.0 <class 'float'>

# %%
timestamp = time.mktime(datetime.today().timetuple())
print(timestamp, type(timestamp))
# Out:
# 1640588790.0 <class 'float'>

# %%
t = time.time()
print(t)
d = datetime.fromtimestamp(t)
print(d, type(d))
# Out:
# 1640588810.718695
# 2021-12-27 07:06:50.718695 <class 'datetime.datetime'>

# %%
import pandas as pd
pd.to_datetime(1640588790,unit='s')
# Out:
# Timestamp('2021-12-27 07:06:30')

# %%
from datetime import timedelta
import time
datetime_now = datetime.now()
delta_datetime = timedelta(days = -365)
print(delta_datetime)
datetime_now + delta_datetime
# Out:
# -365 days, 0:00:00
# datetime.datetime(2020, 12, 27, 7, 8, 33, 672418)

# %%
since_timestamp = datetime.strptime('20211215','%Y%m%d')
until_timestamp = datetime.strptime('20220123','%Y%m%d')
result = until_timestamp - since_timestamp
result
# Out:
# datetime.timedelta(days=39)

# %%
import datetime
def get_yoil(y,m,d):
  days = ['MON','TUE','WED','THU','FRI','SAT','SUN']
  return days[datetime.date(y,m,d).weekday()]
get_yoil(2021,12,27)
# Out:
# 'MON'

# %%
import pandas as pd
date = pd.Timestamp(1640588810.718695,unit='s',tz='Asia/Seoul')
print(date, type(date))
# Out:
# 2021-12-27 16:06:50.718694925+09:00 <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df = pd.read_csv('/content/drive/MyDrive/colab/python basic/dataset/stock-data.csv')
df.head()
# Out:
#          Date  Close  Start   High    Low  Volume
# 0  2018-07-02  10100  10850  10900  10000  137977
# 1  2018-06-29  10700  10550  10900   9990  170253
# 2  2018-06-28  10400  10900  10950  10150  155769
# 3  2018-06-27  10900  10800  11050  10500  133548
# 4  2018-06-26  10800  10900  11000  10700   63039

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Close   20 non-null     int64
#  2   Start   20 non-null     int64
#  3   High    20 non-null     int64
#  4   Low     20 non-null     int64
#  5   Volume  20 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB

# %%
df['New_Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      20 non-null     object
#  1   Close     20 non-null     int64
#  2   Start     20 non-null     int64
#  3   High      20 non-null     int64
#  4   Low       20 non-null     int64
#  5   Volume    20 non-null     int64
#  6   New_Date  20 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 1.2+ KB

# %%
df.drop('Date',axis=1, inplace=True)
df['year'] = df['New_Date'].dt.year
df['month'] = df['New_Date'].dt.month
df['day'] = df['New_Date'].dt.day
df.head()
# Out:
#    Close  Start   High    Low  Volume   New_Date  year  month  day
# 0  10100  10850  10900  10000  137977 2018-07-02  2018      7    2
# 1  10700  10550  10900   9990  170253 2018-06-29  2018      6   29
# 2  10400  10900  10950  10150  155769 2018-06-28  2018      6   28
# 3  10900  10800  11050  10500  133548 2018-06-27  2018      6   27
# 4  10800  10900  11000  10700   63039 2018-06-26  2018      6   26

# %%
df.set_index('New_Date',inplace=True)
df.head()
# Out:
#             Close  Start   High    Low  Volume  year  month  day
# New_Date
# 2018-07-02  10100  10850  10900  10000  137977  2018      7    2
# 2018-06-29  10700  10550  10900   9990  170253  2018      6   29
# 2018-06-28  10400  10900  10950  10150  155769  2018      6   28
# 2018-06-27  10900  10800  11050  10500  133548  2018      6   27
# 2018-06-26  10800  10900  11000  10700   63039  2018      6   26

# %%
df.index
# Out:
# DatetimeIndex(['2018-07-02', '2018-06-29', '2018-06-28', '2018-06-27',
#                '2018-06-26', '2018-06-25', '2018-06-22', '2018-06-21',
#                '2018-06-20', '2018-06-19', '2018-06-18', '2018-06-15',
#                '2018-06-14', '2018-06-12', '2018-06-11', '2018-06-08',
#                '2018-06-07', '2018-06-05', '2018-06-04', '2018-06-01'],
#               dtype='datetime64[ns]', name='New_Date', freq=None)

# %%
df_ymd_range = df['2018-06-29':'2018-06-26']
df_ymd_range
# Out:
#             Close  Start   High    Low  Volume  year  month  day
# New_Date
# 2018-06-29  10700  10550  10900   9990  170253  2018      6   29
# 2018-06-28  10400  10900  10950  10150  155769  2018      6   28
# 2018-06-27  10900  10800  11050  10500  133548  2018      6   27
# 2018-06-26  10800  10900  11000  10700   63039  2018      6   26

# %%
df_ym = df.loc['2018-07','Start':'High']
df_ym
# Out:
#             Start   High
# New_Date
# 2018-07-02  10850  10900

# %%
import numpy as np
import pandas as pd
from datetime import datetime
dates = [datetime(2011,1,2),datetime(2011,1,5),
        datetime(2011,1,7),datetime(2011,1,8),
        datetime(2011,1,10),datetime(2011,1,12)]
ts = pd.Series(np.random.randn(6),index=dates)
ts
# Out:
# 2011-01-02    0.291110
# 2011-01-05   -0.830400
# 2011-01-07   -0.870334
# 2011-01-08   -0.068767
# 2011-01-10   -1.390608
# 2011-01-12   -0.678300
# dtype: float64

# %%
ts.index
# Out:
# DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07', '2011-01-08',
#                '2011-01-10', '2011-01-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
ts[::2]
# Out:
# 2011-01-02    0.291110
# 2011-01-07   -0.870334
# 2011-01-10   -1.390608
# dtype: float64

# %%
ts + ts[::2]
# Out:
# 2011-01-02    0.582221
# 2011-01-05         NaN
# 2011-01-07   -1.740668
# 2011-01-08         NaN
# 2011-01-10   -2.781215
# 2011-01-12         NaN
# dtype: float64

# %%
ts.index[0]
# Out:
# Timestamp('2011-01-02 00:00:00')

# %%
stamp = ts.index[2]
ts[stamp]
# Out:
# -0.8703339974119186

# %%
print(ts['1/10/2011'])
ts['20110110']
# Out:
# -1.3906077365078735
# -1.3906077365078735

# %%
longer_ts = pd.Series(np.random.randn(1000), index = pd.date_range('1/1/2000',periods=1000))
print(longer_ts,'\n')
# Out:
# 2000-01-01    1.445765
# 2000-01-02    0.516120
# 2000-01-03   -0.925107
# 2000-01-04   -0.917956
# 2000-01-05   -0.929216
#                 ...
# 2002-09-22   -1.601991
# 2002-09-23   -0.775763
# 2002-09-24    0.463220
# 2002-09-25   -0.394321
# 2002-09-26    0.678633
# Freq: D, Length: 1000, dtype: float64

# %%
longer_ts['2001-05'][:5]
# Out:
# 2001-05-01    0.903784
# 2001-05-02   -0.289117
# 2001-05-03    0.378980
# 2001-05-04    1.731114
# 2001-05-05    0.120174
# Freq: D, dtype: float64

# %%
ts[datetime(2011,1,7):]
# Out:
# 2011-01-07   -0.870334
# 2011-01-08   -0.068767
# 2011-01-10   -1.390608
# 2011-01-12   -0.678300
# dtype: float64

# %%
ts
# Out:
# 2011-01-02    0.291110
# 2011-01-05   -0.830400
# 2011-01-07   -0.870334
# 2011-01-08   -0.068767
# 2011-01-10   -1.390608
# 2011-01-12   -0.678300
# dtype: float64

# %%
print(ts.truncate(before='2011-01-05',after='2011-01-10'))
# Out:
# 2011-01-05   -0.830400
# 2011-01-07   -0.870334
# 2011-01-08   -0.068767
# 2011-01-10   -1.390608
# dtype: float64

# %%
print(ts.truncate(after='1/9/2011'))
# Out:
# 2011-01-02    0.291110
# 2011-01-05   -0.830400
# 2011-01-07   -0.870334
# 2011-01-08   -0.068767
# dtype: float64

# %%
pd.date_range('2020-10-7','2020-10-20')
# Out:
# DatetimeIndex(['2020-10-07', '2020-10-08', '2020-10-09', '2020-10-10',
#                '2020-10-11', '2020-10-12', '2020-10-13', '2020-10-14',
#                '2020-10-15', '2020-10-16', '2020-10-17', '2020-10-18',
#                '2020-10-19', '2020-10-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
from datetime import datetime
from datetime import timedelta

now = datetime.now()
in_two_weeks = now+timedelta(weeks=2)
pd.date_range(datetime.now(),in_two_weeks)
# Out:
# DatetimeIndex(['2021-12-27 07:24:26.812807', '2021-12-28 07:24:26.812807',
#                '2021-12-29 07:24:26.812807', '2021-12-30 07:24:26.812807',
#                '2021-12-31 07:24:26.812807', '2022-01-01 07:24:26.812807',
#                '2022-01-02 07:24:26.812807', '2022-01-03 07:24:26.812807',
#                '2022-01-04 07:24:26.812807', '2022-01-05 07:24:26.812807',
#                '2022-01-06 07:24:26.812807', '2022-01-07 07:24:26.812807',
#                '2022-01-08 07:24:26.812807', '2022-01-09 07:24:26.812807'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2020-10-01',end='2020-10-20',periods=5)
# Out:
# DatetimeIndex(['2020-10-01 00:00:00', '2020-10-05 18:00:00',
#                '2020-10-10 12:00:00', '2020-10-15 06:00:00',
#                '2020-10-20 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.date_range('2012-05-02 12:56:31',periods=5, normalize=True)
# Out:
# DatetimeIndex(['2012-05-02', '2012-05-03', '2012-05-04', '2012-05-05',
#                '2012-05-06'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# freq 매개변수에 사용되는 Frequncy strings
# - A calendar year end frequency
# - B	business day frequency
# - C	custom business day frequency
# - D	calendar day frequency
# - W	weekly frequency
# - M	month end frequency
# - SM	semi-month end frequency (15th and end of month)
# - BM	business month end frequency
# - CBM	custom business month end frequency
# - MS	month start frequency
# - SMS	semi-month start frequency (1st and 15th)
# - BMS	business month start frequency
# - CBMS	custom business month start frequency
# - Q	quarter end frequency

# %%
import numpy as np
dates = pd.date_range('1/1/2000', periods = 100, freq='W-WED')
print(dates)
# Out:
# DatetimeIndex(['2000-01-05', '2000-01-12', '2000-01-19', '2000-01-26',
#                '2000-02-02', '2000-02-09', '2000-02-16', '2000-02-23',
#                '2000-03-01', '2000-03-08', '2000-03-15', '2000-03-22',
#                '2000-03-29', '2000-04-05', '2000-04-12', '2000-04-19',
#                '2000-04-26', '2000-05-03', '2000-05-10', '2000-05-17',
#                '2000-05-24', '2000-05-31', '2000-06-07', '2000-06-14',
#                '2000-06-21', '2000-06-28', '2000-07-05', '2000-07-12',
#                '2000-07-19', '2000-07-26', '2000-08-02', '2000-08-09',
#                '2000-08-16', '2000-08-23', '2000-08-30', '2000-09-06',
#                '2000-09-13', '2000-09-20', '2000-09-27', '2000-10-04',
#                '2000-10-11', '2000-10-18', '2000-10-25', '2000-11-01',
#                '2000-11-08', '2000-11-15', '2000-11-22', '2000-11-29',
#                '2000-12-06', '2000-12-13', '2000-12-20', '2000-12-27',
#                '2001-01-03', '2001-01-10', '2001-01-17', '2001-01-24',
#                '2001-01-31', '2001-02-07', '2001-02-14', '2001-02-21',
#                '2001-02-28', '2001-03-07', '2001-03-14', '2001-03-21',
#                '2001-03-28', '2001-04-04', '2001-04-11', '2001-04-18',
#                '2001-04-25', '2001-05-02', '2001-05-09', '2001-05-16',
#                '2001-05-23', '2001-05-30', '2001-06-06', '2001-06-13',
#                '2001-06-20', '2001-06-27', '2001-07-04', '2001-07-11',
#                '2001-07-18', '2001-07-25', '2001-08-01', '2001-08-08',
#                '2001-08-15', '2001-08-22', '2001-08-29', '2001-09-05',
#                '2001-09-12', '2001-09-19', '2001-09-26', '2001-10-03',
#                '2001-10-10', '2001-10-17', '2001-10-24', '2001-10-31',
#                '2001-11-07', '2001-11-14', '2001-11-21', '2001-11-28'],
#               dtype='datetime64[ns]', freq='W-WED')

# %%
long_df = pd.DataFrame(np.random.randn(100,4),index=dates, columns=['Colorado','Texas','New York','Ohio'])
print(long_df, '\n')
long_df.loc['2001-06']
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05 -0.227965 -0.149420 -0.365111 -0.287647
# 2000-01-12 -0.917794 -0.998906  0.863370 -0.324265
# 2000-01-19  0.555292 -0.926767  0.305578 -1.078394
# 2000-01-26 -0.345114 -1.555563 -0.690824 -0.386572
# 2000-02-02 -0.995716  0.496498 -1.243863 -0.595676
# ...              ...       ...       ...       ...
# 2001-10-31 -0.747825  0.479989  0.187404 -2.088760
# 2001-11-07  0.548028 -0.630384  2.263211  0.119379
# 2001-11-14  0.609843 -0.178644 -0.185295  0.166580
# 2001-11-21  2.066755 -0.095929 -2.328064  0.908324
# 2001-11-28 -0.941890 -0.905398  0.694834  0.546374
#
# [100 rows x 4 columns]
#             Colorado     Texas  New York      Ohio
# 2001-06-06  1.902890 -0.482069 -1.453901  0.626975
# 2001-06-13  0.771560 -0.372770 -0.448194 -0.208313
# 2001-06-20 -0.003213  0.948301 -0.900754  0.428236
# 2001-06-27 -0.714620  0.439818 -0.670437  2.948813

# %%
dates = pd.DatetimeIndex(['1/1/2000','1/2/2000','1/2/2000','1/2/2000','1/3/2000'])
dup_ts = pd.Series(np.arange(5),index=dates)
dup_ts
# Out:
# 2000-01-01    0
# 2000-01-02    1
# 2000-01-02    2
# 2000-01-02    3
# 2000-01-03    4
# dtype: int64

# %%
dup_ts.index.is_unique
# Out:
# False

# %%
dup_ts['1/2/2000']
# Out:
# 2000-01-02    1
# 2000-01-02    2
# 2000-01-02    3
# dtype: int64

# %%
grouped = dup_ts.groupby(level=0)
print(grouped.mean())
grouped.count()
# Out:
# 2000-01-01    0
# 2000-01-02    2
# 2000-01-03    4
# dtype: int64
# 2000-01-01    1
# 2000-01-02    3
# 2000-01-03    1
# dtype: int64

# %%
pd.date_range('2000-01-01','2000-01-03 23:59',freq='4h')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 04:00:00',
#                '2000-01-01 08:00:00', '2000-01-01 12:00:00',
#                '2000-01-01 16:00:00', '2000-01-01 20:00:00',
#                '2000-01-02 00:00:00', '2000-01-02 04:00:00',
#                '2000-01-02 08:00:00', '2000-01-02 12:00:00',
#                '2000-01-02 16:00:00', '2000-01-02 20:00:00',
#                '2000-01-03 00:00:00', '2000-01-03 04:00:00',
#                '2000-01-03 08:00:00', '2000-01-03 12:00:00',
#                '2000-01-03 16:00:00', '2000-01-03 20:00:00'],
#               dtype='datetime64[ns]', freq='4H')

# %%
from pandas.tseries.offsets import Hour, Minute
Hour(2) + Minute(30)
# Out:
# <150 * Minutes>

# %%
pd.date_range('2000-01-01',periods=10,freq='1h30min')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 01:30:00',
#                '2000-01-01 03:00:00', '2000-01-01 04:30:00',
#                '2000-01-01 06:00:00', '2000-01-01 07:30:00',
#                '2000-01-01 09:00:00', '2000-01-01 10:30:00',
#                '2000-01-01 12:00:00', '2000-01-01 13:30:00'],
#               dtype='datetime64[ns]', freq='90T')

# %%
rng = pd.date_range('2000-01-01','2012-09-01',freq='WOM-3FRI')
print(rng)
# Out:
# DatetimeIndex(['2000-01-21', '2000-02-18', '2000-03-17', '2000-04-21',
#                '2000-05-19', '2000-06-16', '2000-07-21', '2000-08-18',
#                '2000-09-15', '2000-10-20',
#                ...
#                '2011-11-18', '2011-12-16', '2012-01-20', '2012-02-17',
#                '2012-03-16', '2012-04-20', '2012-05-18', '2012-06-15',
#                '2012-07-20', '2012-08-17'],
#               dtype='datetime64[ns]', length=152, freq='WOM-3FRI')

# %%
from pandas.tseries.offsets import Day, MonthEnd
now = datetime(2011,11,17)
now + 3*Day()
# Out:
# Timestamp('2011-11-20 00:00:00')

# %%
offset = MonthEnd()
print(offset.rollforward(now))
offset.rollback(now)
# Out:
# 2011-11-30 00:00:00
# Timestamp('2011-10-31 00:00:00')

# %%
ts = pd.Series(np.random.randn(20),index=pd.date_range('1/15/2000',periods=20,freq='4d'))
print(ts)
# Out:
# 2000-01-15   -1.652794
# 2000-01-19   -1.341397
# 2000-01-23    0.359600
# 2000-01-27    0.135643
# 2000-01-31   -0.016980
# 2000-02-04    0.055572
# 2000-02-08    0.498011
# 2000-02-12   -0.677509
# 2000-02-16   -0.014007
# 2000-02-20   -0.908376
# 2000-02-24   -0.892009
# 2000-02-28   -0.664852
# 2000-03-03    0.982223
# 2000-03-07    1.290020
# 2000-03-11   -0.100315
# 2000-03-15   -0.776997
# 2000-03-19    1.672155
# 2000-03-23   -0.832445
# 2000-03-27   -0.567624
# 2000-03-31    0.885404
# Freq: 4D, dtype: float64

# %%
import pandas as pd
p = pd.Period(2007, freq='A-DEC')
p
# Out:
# Period('2007', 'A-DEC')

# %%
print(p+5)
# Out:
# 2012

# %%
p-2
# Out:
# Period('2005', 'A-DEC')

# %%
import numpy as np
rng = pd.period_range('2000-01-01',periods=3, freq='M')
ts = pd.Series(np.random.randn(3),index=rng)
print(ts,'\n')
ts.to_timestamp(how='end')
# Out:
# 2000-01   -0.693027
# 2000-02   -0.322584
# 2000-03   -0.822293
# Freq: M, dtype: float64
# 2000-01-31 23:59:59.999999999   -0.693027
# 2000-02-29 23:59:59.999999999   -0.322584
# 2000-03-31 23:59:59.999999999   -0.822293
# dtype: float64

# %%
rng = pd.date_range('2001-01-01',periods=12, freq='T')
ts = pd.Series(np.arange(12),index=rng)
ts
# Out:
# 2001-01-01 00:00:00     0
# 2001-01-01 00:01:00     1
# 2001-01-01 00:02:00     2
# 2001-01-01 00:03:00     3
# 2001-01-01 00:04:00     4
# 2001-01-01 00:05:00     5
# 2001-01-01 00:06:00     6
# 2001-01-01 00:07:00     7
# 2001-01-01 00:08:00     8
# 2001-01-01 00:09:00     9
# 2001-01-01 00:10:00    10
# 2001-01-01 00:11:00    11
# Freq: T, dtype: int64

# %%
ts.resample('5min',closed='right').sum()
# Out:
# 2000-12-31 23:55:00     0
# 2001-01-01 00:00:00    15
# 2001-01-01 00:05:00    40
# 2001-01-01 00:10:00    11
# Freq: 5T, dtype: int64

# %%
ts.resample('5min').ohlc()
# Out:
#                      open  high  low  close
# 2001-01-01 00:00:00     0     4    0      4
# 2001-01-01 00:05:00     5     9    5      9
# 2001-01-01 00:10:00    10    11   10     11

# %%
frame = pd.DataFrame(np.random.randn(2,4),index=pd.date_range('1/1/2000',periods=2,freq='W-WED'),columns=['Colorado','Texas','New York','Ohio'])
frame
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05  0.718138  1.067272  1.275908 -0.361487
# 2000-01-12 -0.085332 -0.181583  0.247511  0.318275

# %%
df_daily = frame.resample('D').asfreq()
df_daily
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05  0.718138  1.067272  1.275908 -0.361487
# 2000-01-06       NaN       NaN       NaN       NaN
# 2000-01-07       NaN       NaN       NaN       NaN
# 2000-01-08       NaN       NaN       NaN       NaN
# 2000-01-09       NaN       NaN       NaN       NaN
# 2000-01-10       NaN       NaN       NaN       NaN
# 2000-01-11       NaN       NaN       NaN       NaN
# 2000-01-12 -0.085332 -0.181583  0.247511  0.318275

# %%
frame.resample('D').ffill()
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05  0.718138  1.067272  1.275908 -0.361487
# 2000-01-06  0.718138  1.067272  1.275908 -0.361487
# 2000-01-07  0.718138  1.067272  1.275908 -0.361487
# 2000-01-08  0.718138  1.067272  1.275908 -0.361487
# 2000-01-09  0.718138  1.067272  1.275908 -0.361487
# 2000-01-10  0.718138  1.067272  1.275908 -0.361487
# 2000-01-11  0.718138  1.067272  1.275908 -0.361487
# 2000-01-12 -0.085332 -0.181583  0.247511  0.318275

# %%
frame.resample('D').ffill(limit=2)
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05  0.718138  1.067272  1.275908 -0.361487
# 2000-01-06  0.718138  1.067272  1.275908 -0.361487
# 2000-01-07  0.718138  1.067272  1.275908 -0.361487
# 2000-01-08       NaN       NaN       NaN       NaN
# 2000-01-09       NaN       NaN       NaN       NaN
# 2000-01-10       NaN       NaN       NaN       NaN
# 2000-01-11       NaN       NaN       NaN       NaN
# 2000-01-12 -0.085332 -0.181583  0.247511  0.318275
