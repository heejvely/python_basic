# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/colab/python basic/누구나_파이썬_통계분석/dataset/ch1_sport_test.csv')

df
# Out:
#    학생번호  학년    악력  윗몸일으키기  점수  순위
# 0     1   1  40.2      34  15   4
# 1     2   1  34.2      14   7  10
# 2     3   1  28.8      27  11   7
# 3     4   2  39.0      27  14   5
# 4     5   2  50.9      32  17   2
# 5     6   2  36.5      20   9   9
# 6     7   3  36.6      31  13   6
# 7     8   3  49.2      37  18   1
# 8     9   3  26.0      28  10   8
# 9    10   3  47.4      32  16   3

# %%
df['악력']
# Out:
# 0    40.2
# 1    34.2
# 2    28.8
# 3    39.0
# 4    50.9
# 5    36.5
# 6    36.6
# 7    49.2
# 8    26.0
# 9    47.4
# Name: 악력, dtype: float64

# %% [markdown]
# ## 1.1 데이터의 크기

# %%
df.shape
# Out:
# (10, 6)

# %% [markdown]
# ## 1.2 변수의 종류

# %% [markdown]
# - 질적변수: 종류를 구별하기 위한 변수
# - 양적변수: 양을 표현하는 변수

# %% [markdown]
# - 명의 척도: 단순히 분류하기 위한 변수
# - 순서 척도: 순서 관계나 대소 관계에 의미가 있는 변수
# - 간격 척도: 대소 관계와 함께 그 차이에도 의미를 두는 변수
# - 비례 척도: 대소 관계, 차이, 비 모두에 의미가 있는 변수

# %% [markdown]
# - 이산형 변수: 하나하나의 값을 취하는 변수, 서로 인접한 숫자 사이에 값이 존재 하지 않음.
# - 연속형 변수: 연속적인 값은 취할 수 있는 변수, 어떤 두 숫자 사이에도 반드시 숫자가 존재함.
